# %%
from osa_simple import YeniOSA
import matplotlib.pyplot as plt
import time

# %%
osa = YeniOSA()
osa.connect()

# %%
CENTER = 1550
SPAN = 180
RESOLUTION = 0.2
SENSITIVITY = -70

osa.setup_sweep(
    center_nm=CENTER,
    span_nm=SPAN,
    resolution_nm=RESOLUTION,
    sensitivity_dbm=SENSITIVITY,
)

# %%
osa.run_sweep(
trace=1,
averages=1,
progress_poll_s=0.5,
start_delay_s=2.0,
)

trace = osa.get_trace(
    trace=1,
    metadata_poll_s=0.2,
    metadata_retries=5,
)
# Out:
# Trace 1 activated.
# Running single sweep.
# Previous trace cleared.
# Sweep started.
# Sweep progress: 100.0%
# Sweep completed.
# Waiting for trace metadata
# Trace consulting ...
# Metadata not ready (1/5)
# Trace consulting ...
# Metadata available.
# Reading trace metadata...
# Trace points reported by OSA: 90001
# Reading trace power data...

# %%
from datetime import datetime

N = 2

for i in range(N):

    print(f"\n========== Sweep {i+1}/{N} ==========")

    try:

        osa.run_sweep(
            trace=1,
            averages=1,
            progress_poll_s=0.5,
            start_delay_s=2.0,
        )

        trace = osa.get_trace(
            trace=1,
            metadata_poll_s=0.2,
            metadata_retries=5,
        )

        filename = (
            f"data/test_{i+1}_"
            f"{datetime.now():%Y%m%d_%H%M%S}.txt"
        )

        trace.save_txt(filename)

        print(f"✓ Saved: {filename}")

    except Exception as e:

        print(f"✗ Sweep {i+1} failed")
        print(e)
# Out:
# ========== Sweep 1/2 ==========
# Trace 1 activated.
# Running single sweep.
# Previous trace cleared.
# Sweep started.
# Sweep progress: 100.0%
# Sweep completed.
# Waiting for trace metadata
# Trace consulting ...
# Metadata not ready (1/5)
# Trace consulting ...
# Metadata available.
# Reading trace metadata...
# Trace points reported by OSA: 90001
# Reading trace power data...
# ✓ Saved: data/test_1_20260715_104112.txt
#
# ========== Sweep 2/2 ==========
# Trace 1 activated.
# Running single sweep.
# Previous trace cleared.
# Sweep started.
# Sweep progress: 100.0%
# Sweep completed.
# Waiting for trace metadata
# Trace consulting ...
# Metadata not ready (1/5)
# Trace consulting ...
# Metadata available.
# Reading trace metadata...
# Trace points reported by OSA: 90001
# Reading trace power data...
# ✓ Saved: data/test_2_20260715_104711.txt

# %%
plt.figure(figsize=(10,5))

plt.plot(
    trace.wavelength_nm,
    trace.power_dbm
)

plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Potencia (dBm)")
plt.grid(True)

# %% [markdown]
# Este codigo lo probamos con la esperanza de corregir el error de que la lectura no estaba disponible al momento de hacer la lectura.

# %%
osa.run_sweep(
trace=1,
averages=1,
progress_poll_s=0.5,
start_delay_s=2.0,
)

time.sleep(2)

trace = osa.get_trace(1)
# Out:
# Trace 1 activated.
# Running single sweep.
# Previous trace cleared.
# Sweep started.
# Sweep progress: 100.0%
# Sweep completed.
# Reading trace metadata...
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# Cell In[17], line 8
#       4 progress_poll_s=0.5,
#       5 start_delay_s=2.0,
#       6 )
#       7
# ----> 8 trace = osa.get_trace(1)
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\OSA\osa_simple.py:194, in YeniOSA.get_trace(self, trace, read_timeout_s)
#     192 def get_trace(self, trace=1, read_timeout_s=120):
#     193     print("Reading trace metadata...")
# --> 194     start_m = float(self.query(f":TRACe{trace}:DATA:STAR?"))
#     195     step_m = float(self.query(f":TRACe{trace}:DATA:SAMP?"))
#     196     npoints = int(float(self.query(f":TRACe{trace}:DATA:LENG?")))
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\OSA\osa_simple.py:86, in SimpleVisaInstrument.query(self, command)
#      85 def query(self, command):
# ---> 86     return self.inst.query(command).strip()
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\resources\messagebased.py:702, in MessageBasedResource.query(self, message, delay)
#     699 if delay > 0.0:
#     700     time.sleep(delay)
# --> 702 return self.read()
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\resources\messagebased.py:521, in MessageBasedResource.read(self, termination, encoding)
#     519 if termination is None:
#     520     termination = self._read_termination
# --> 521     message = self._read_raw().decode(enco)
#     522 else:
#     523     with self.read_termination_context(termination):
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\resources\messagebased.py:475, in MessageBasedResource._read_raw(self, size, monitoring_interface)
#     468 while status == loop_status:
#     469     logger.debug(
#     470         "%s - reading %d bytes (last status %r)",
#     471         self._resource_name,
#     472         size,
#     473         status,
#     474     )
# --> 475     chunk, status = self.visalib.read(self.session, size)
#     476     if monitoring_interface:
#     477         monitoring_interface.update(len(chunk))
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\ctwrapper\functions.py:2339, in read(library, session, count)
#    2337 buffer = create_string_buffer(count)
#    2338 return_count = ViUInt32()
# -> 2339 ret = library.viRead(session, buffer, count, byref(return_count))
#    2340 return buffer.raw[: return_count.value], ret
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\ctwrapper\highlevel.py:227, in IVIVisaLibrary._return_handler(self, ret_value, func, arguments)
#     224         # Set session back to a safe value
#     225         session = None
# --> 227 return self.handle_return_value(session, ret_value)
#
# File d:\Documentos\lab_repos\SurugaSeikiHex\.venv\Lib\site-packages\pyvisa\highlevel.py:252, in VisaLibraryBase.handle_return_value(self, session, status_code)
#     249     self._last_status_in_session[session] = rv
#     251 if rv < 0:
# --> 252     raise errors.VisaIOError(rv)
#     254 if rv in self.issue_warning_on:
#     255     if session and rv not in self._ignore_warning_in_session[session]:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.

# %%
osa.close()
