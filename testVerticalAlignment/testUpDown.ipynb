# %%
from pic_upv.suruga import System, AxisComponents, Alignment, PowerMeter

# %%
suruga = System()
y2 = AxisComponents(suruga, "y2")
suruga.connect()
# Out:
# Conectando al equipo Suruga-Seiki...
# Dirección: 5.113.249.131.1.1
# Versión DLL: 1.3.4.0
# Intentando conectar... False
# Intentando conectar... False
# True

# %%
y2.move_relative(-2.0, speed=20.0)
# Out:
# <ErrorCode.None: 0>
