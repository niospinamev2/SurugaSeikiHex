# %%
from pic_upv.control_suruga_class import SurugaController

suruga = SurugaController()

# %%
suruga.saludo()
# Out:
# Hola desde SurugaController

# %%
suruga.conectar()

# %%
pos = suruga.leer_posicion(1)
print(pos)
# Out:
# -19999.989999999998

# %%
suruga.mover_eje(
    axis_number=1,
    distance=-5000,
)
# Out:
# Conectando al equipo Suruga-Seiki...
# Dirección: 5.113.249.131.1.1
# Versión DLL: 1.3.4.0
# Posición inicial: -35062.42
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 suruga.mover_eje(
#       2     axis_number=1,
#       3     distance=-5000,
#       4 )
#
# File D:\Documentos\lab_repos\SurugaSeikiHex\src\pic_upv\control_suruga_class.py:145, in SurugaController.mover_eje(self, axis_number, distance, max_speed, timeout_s)
#     136     raise RuntimeError(
#     137         "El eje está en alarma."
#     138     )
#     140 if (
#     141     axis.IsCwLimitSignalOn()
#     142     or axis.IsCcwLimitSignalOn()
#     143 ):
# --> 145     raise RuntimeError(
#     146         "El eje está en un límite."
#     147     )
#     149 if not axis.IsServoOn():
#     151     print("Activando servo...")
#
# RuntimeError: El eje está en un límite.

# %%
pos = suruga.leer_posicion(1)
print(pos)
# Out:
# -24999.99
