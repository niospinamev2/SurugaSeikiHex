# %%
from pic_upv.control_suruga_class import SurugaController

suruga = SurugaController()

# %%
suruga.saludo()
# Out:
# Hola desde SurugaController

# %%
pos = suruga.leer_posicion(7)
print(pos)
# Out:
# -25000.0

# %%
suruga.mover_eje(
    axis_number=7,
    distance=5000,
)
# Out:
# Conectando al equipo Suruga-Seiki...
# Dirección: 5.113.249.131.1.1
# Versión DLL: 1.3.4.0
# Posición inicial: -25000.0
# Moviendo eje 7
# Moviendo... posición: -24999.82
# Moviendo... posición: -24792.19
# Moviendo... posición: -24585.91
# Moviendo... posición: -24380.01
# Moviendo... posición: -24173.82
# Moviendo... posición: -23966.96
# Moviendo... posición: -23761.05
# Moviendo... posición: -23553.91
# Moviendo... posición: -23348.1
# Moviendo... posición: -23141.89
# Moviendo... posición: -22937.05
# Moviendo... posición: -22727.04
# Moviendo... posición: -22521.09
# Moviendo... posición: -22314.91
# Moviendo... posición: -22109.19
# Moviendo... posición: -21902.06
# Moviendo... posición: -21697.84
# Moviendo... posición: -21493.93
# Moviendo... posición: -21290.15
# Moviendo... posición: -21085.83
# Moviendo... posición: -20874.95
# Moviendo... posición: -20669.13
# Moviendo... posición: -20463.82
# Moviendo... posición: -20260.0
# Moviendo... posición: -20053.9
# Posición final: -19999.89

# %%
pos = suruga.leer_posicion(7)
print(pos)
# Out:
# -20000.0
